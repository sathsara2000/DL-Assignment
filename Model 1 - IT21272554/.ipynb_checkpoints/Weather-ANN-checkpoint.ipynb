# %% [markdown]
# Import the libraries

# %% [markdown]
# # ANN Regression Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Import the dataset

# %%
dataset=pd.read_csv("preprocessed_weather.csv")
X=dataset.iloc[:,[i for i in range(13)if i!=7] ].values
Y=dataset.iloc[:,7:8].values

# %% [markdown]
# Spliit the data in to test and training

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y, test_size=0.25, random_state=42)

# %% [markdown]
# scaling the features

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Build the ANN model

# %%
# Define the model
ann = models.Sequential()

# First Dense layer with Dropout
ann.add(layers.Dense(256, activation='relu', input_shape=(x_train.shape[1],)))
ann.add(layers.Dropout(0.3))  # Dropout rate of 30%


# Second Dense layer with Dropout
ann.add(layers.Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
ann.add(layers.Dropout(0.3))  

# Third Dense layer with Dropout
ann.add(layers.Dense(32, activation='relu'))
ann.add(layers.Dropout(0.3))  # Dropout rate of 30%

# Output layer
ann.add(layers.Dense(1, activation='linear'))

# %% [markdown]
# Compile the model

# %%
ann.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %% [markdown]
# Train the model

# %%
ann.fit(x_train_scaled,y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 1664/1664 [==============================] - 5s 2ms/step - loss: 7.5150 - mae: 1.9657 - val_loss: 4.8328 - val_mae: 1.5664
# Epoch 2/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 6.1854 - mae: 1.7566 - val_loss: 4.6190 - val_mae: 1.5145
# Epoch 3/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 5.8347 - mae: 1.6976 - val_loss: 4.7617 - val_mae: 1.5210
# Epoch 4/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 5.6217 - mae: 1.6591 - val_loss: 4.4320 - val_mae: 1.4731
# Epoch 5/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 5.4815 - mae: 1.6402 - val_loss: 4.4669 - val_mae: 1.5020
# Epoch 6/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 5.3465 - mae: 1.6148 - val_loss: 4.4329 - val_mae: 1.4454
# Epoch 7/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 5.2739 - mae: 1.6036 - val_loss: 4.5600 - val_mae: 1.4713
# Epoch 8/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 5.1529 - mae: 1.5817 - val_loss: 4.2678 - val_mae: 1.4428
# Epoch 9/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 5.0854 - mae: 1.5693 - val_loss: 4.2402 - val_mae: 1.4252
# Epoch 10/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 5.0085 - mae: 1.5559 - val_loss: 4.2642 - val_mae: 1.4258
# Epoch 11/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.9846 - mae: 1.5518 - val_loss: 4.1928 - val_mae: 1.4246
# Epoch 12/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.9451 - mae: 1.5444 - val_loss: 4.1975 - val_mae: 1.4144
# Epoch 13/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.9147 - mae: 1.5367 - val_loss: 4.2233 - val_mae: 1.3969
# Epoch 14/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.8691 - mae: 1.5284 - val_loss: 4.2195 - val_mae: 1.4520
# Epoch 15/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.8326 - mae: 1.5261 - val_loss: 4.2389 - val_mae: 1.3905
# Epoch 16/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.7980 - mae: 1.5166 - val_loss: 4.1152 - val_mae: 1.3871
# Epoch 17/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.7798 - mae: 1.5137 - val_loss: 4.1894 - val_mae: 1.4573
# Epoch 18/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.7366 - mae: 1.5107 - val_loss: 4.0616 - val_mae: 1.3829
# Epoch 19/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.7510 - mae: 1.5107 - val_loss: 4.0209 - val_mae: 1.3693
# Epoch 20/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.7237 - mae: 1.5050 - val_loss: 4.0763 - val_mae: 1.3630
# Epoch 21/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.7079 - mae: 1.5051 - val_loss: 4.0617 - val_mae: 1.3900
# Epoch 22/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.6625 - mae: 1.4982 - val_loss: 3.9700 - val_mae: 1.3736
# Epoch 23/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.6669 - mae: 1.4982 - val_loss: 4.0026 - val_mae: 1.3332
# Epoch 24/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.6476 - mae: 1.4923 - val_loss: 4.0297 - val_mae: 1.3775
# Epoch 25/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.6242 - mae: 1.4903 - val_loss: 3.9769 - val_mae: 1.3781
# Epoch 26/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.6103 - mae: 1.4910 - val_loss: 4.1006 - val_mae: 1.4054
# Epoch 27/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.5982 - mae: 1.4880 - val_loss: 3.9899 - val_mae: 1.3744
# Epoch 28/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.5998 - mae: 1.4887 - val_loss: 3.8794 - val_mae: 1.3186
# Epoch 29/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.5609 - mae: 1.4810 - val_loss: 4.0159 - val_mae: 1.3572
# Epoch 30/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.5623 - mae: 1.4783 - val_loss: 3.9514 - val_mae: 1.3865
# Epoch 31/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.5011 - mae: 1.4730 - val_loss: 3.8932 - val_mae: 1.3680
# Epoch 32/100
# 1664/1664 [==============================] - 5s 3ms/step - loss: 4.5302 - mae: 1.4759 - val_loss: 3.9413 - val_mae: 1.3840
# Epoch 33/100
# 1664/1664 [==============================] - 6s 4ms/step - loss: 4.5092 - mae: 1.4728 - val_loss: 3.8452 - val_mae: 1.3033
# Epoch 34/100
# 1664/1664 [==============================] - 6s 4ms/step - loss: 4.4809 - mae: 1.4693 - val_loss: 3.8939 - val_mae: 1.3509
# Epoch 35/100
# 1664/1664 [==============================] - 6s 4ms/step - loss: 4.5011 - mae: 1.4723 - val_loss: 3.8428 - val_mae: 1.3263
# Epoch 36/100
# 1664/1664 [==============================] - 6s 4ms/step - loss: 4.4913 - mae: 1.4704 - val_loss: 3.8923 - val_mae: 1.3133
# Epoch 37/100
# 1664/1664 [==============================] - 6s 3ms/step - loss: 4.4690 - mae: 1.4666 - val_loss: 3.8204 - val_mae: 1.2918
# Epoch 38/100
# 1664/1664 [==============================] - 6s 3ms/step - loss: 4.4544 - mae: 1.4624 - val_loss: 3.8493 - val_mae: 1.3721
# Epoch 39/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.4591 - mae: 1.4636 - val_loss: 3.8781 - val_mae: 1.3242
# Epoch 40/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.4045 - mae: 1.4566 - val_loss: 3.8217 - val_mae: 1.3243
# Epoch 41/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.4243 - mae: 1.4570 - val_loss: 3.7307 - val_mae: 1.2768
# Epoch 42/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.3824 - mae: 1.4487 - val_loss: 3.8667 - val_mae: 1.3215
# Epoch 43/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3881 - mae: 1.4498 - val_loss: 3.7556 - val_mae: 1.3255
# Epoch 44/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3889 - mae: 1.4530 - val_loss: 3.7529 - val_mae: 1.2945
# Epoch 45/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3879 - mae: 1.4516 - val_loss: 3.7182 - val_mae: 1.2997
# Epoch 46/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.3858 - mae: 1.4506 - val_loss: 3.7422 - val_mae: 1.2970
# Epoch 47/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.3277 - mae: 1.4411 - val_loss: 3.8061 - val_mae: 1.3204
# Epoch 48/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3556 - mae: 1.4485 - val_loss: 3.8701 - val_mae: 1.3706
# Epoch 49/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3202 - mae: 1.4430 - val_loss: 3.7379 - val_mae: 1.2860
# Epoch 50/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2819 - mae: 1.4334 - val_loss: 3.7563 - val_mae: 1.3269
# Epoch 51/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2936 - mae: 1.4355 - val_loss: 3.6683 - val_mae: 1.2893
# Epoch 52/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3342 - mae: 1.4425 - val_loss: 3.7356 - val_mae: 1.3051
# Epoch 53/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.3039 - mae: 1.4387 - val_loss: 3.6773 - val_mae: 1.3005
# Epoch 54/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2851 - mae: 1.4375 - val_loss: 3.6903 - val_mae: 1.2906
# Epoch 55/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2521 - mae: 1.4334 - val_loss: 3.7295 - val_mae: 1.3230
# Epoch 56/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.2795 - mae: 1.4359 - val_loss: 3.7489 - val_mae: 1.3139
# Epoch 57/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2368 - mae: 1.4278 - val_loss: 3.6888 - val_mae: 1.3051
# Epoch 58/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.2480 - mae: 1.4290 - val_loss: 3.6852 - val_mae: 1.3148
# Epoch 59/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.2137 - mae: 1.4253 - val_loss: 3.6810 - val_mae: 1.2870
# Epoch 60/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.2122 - mae: 1.4236 - val_loss: 3.6395 - val_mae: 1.2976
# Epoch 61/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.2194 - mae: 1.4251 - val_loss: 3.6761 - val_mae: 1.3243
# Epoch 62/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1838 - mae: 1.4189 - val_loss: 3.6471 - val_mae: 1.2890
# Epoch 63/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.1740 - mae: 1.4152 - val_loss: 3.6652 - val_mae: 1.3128
# Epoch 64/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1781 - mae: 1.4159 - val_loss: 3.6492 - val_mae: 1.2838
# Epoch 65/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1728 - mae: 1.4163 - val_loss: 3.6072 - val_mae: 1.2945
# Epoch 66/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1964 - mae: 1.4180 - val_loss: 3.6404 - val_mae: 1.2883
# Epoch 67/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.1750 - mae: 1.4127 - val_loss: 3.6872 - val_mae: 1.3130
# Epoch 68/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.1683 - mae: 1.4139 - val_loss: 3.5978 - val_mae: 1.2689
# Epoch 69/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1715 - mae: 1.4162 - val_loss: 3.5710 - val_mae: 1.2657
# Epoch 70/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1644 - mae: 1.4182 - val_loss: 3.5584 - val_mae: 1.2774
# Epoch 71/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1294 - mae: 1.4084 - val_loss: 3.5678 - val_mae: 1.2649
# Epoch 72/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.0927 - mae: 1.4025 - val_loss: 3.6206 - val_mae: 1.3222
# Epoch 73/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.1061 - mae: 1.4046 - val_loss: 3.5905 - val_mae: 1.3011
# Epoch 74/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.1253 - mae: 1.4083 - val_loss: 3.5988 - val_mae: 1.2549
# Epoch 75/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.1109 - mae: 1.4049 - val_loss: 3.5848 - val_mae: 1.2817
# Epoch 76/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.1107 - mae: 1.4039 - val_loss: 3.5538 - val_mae: 1.2644
# Epoch 77/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0728 - mae: 1.4036 - val_loss: 3.5247 - val_mae: 1.2607
# Epoch 78/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0691 - mae: 1.3968 - val_loss: 3.5164 - val_mae: 1.2771
# Epoch 79/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0742 - mae: 1.3984 - val_loss: 3.4904 - val_mae: 1.2779
# Epoch 80/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0611 - mae: 1.3954 - val_loss: 3.5240 - val_mae: 1.2781
# Epoch 81/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.0521 - mae: 1.3948 - val_loss: 3.5301 - val_mae: 1.2604
# Epoch 82/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0925 - mae: 1.4028 - val_loss: 3.6033 - val_mae: 1.2690
# Epoch 83/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0632 - mae: 1.3966 - val_loss: 3.5134 - val_mae: 1.2295
# Epoch 84/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0471 - mae: 1.3941 - val_loss: 3.5518 - val_mae: 1.2804
# Epoch 85/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0640 - mae: 1.3988 - val_loss: 3.5340 - val_mae: 1.2782
# Epoch 86/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0896 - mae: 1.3991 - val_loss: 3.5330 - val_mae: 1.2780
# Epoch 87/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0380 - mae: 1.3933 - val_loss: 3.5195 - val_mae: 1.2996
# Epoch 88/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0305 - mae: 1.3924 - val_loss: 3.5535 - val_mae: 1.2801
# Epoch 89/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0546 - mae: 1.3954 - val_loss: 3.4600 - val_mae: 1.2326
# Epoch 90/100
# 1664/1664 [==============================] - 4s 3ms/step - loss: 4.0270 - mae: 1.3935 - val_loss: 3.4881 - val_mae: 1.2814
# Epoch 91/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0162 - mae: 1.3916 - val_loss: 3.4175 - val_mae: 1.2230
# Epoch 92/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0086 - mae: 1.3892 - val_loss: 3.4583 - val_mae: 1.2650
# Epoch 93/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0168 - mae: 1.3919 - val_loss: 3.4996 - val_mae: 1.2335
# Epoch 94/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0170 - mae: 1.3925 - val_loss: 3.4794 - val_mae: 1.2748
# Epoch 95/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 4.0246 - mae: 1.3925 - val_loss: 3.3971 - val_mae: 1.2354
# Epoch 96/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0124 - mae: 1.3919 - val_loss: 3.4681 - val_mae: 1.2375
# Epoch 97/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 3.9782 - mae: 1.3825 - val_loss: 3.4681 - val_mae: 1.2886
# Epoch 98/100
# 1664/1664 [==============================] - 3s 2ms/step - loss: 4.0010 - mae: 1.3898 - val_loss: 3.3654 - val_mae: 1.2208
# Epoch 99/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 3.9474 - mae: 1.3793 - val_loss: 3.4267 - val_mae: 1.2409
# Epoch 100/100
# 1664/1664 [==============================] - 4s 2ms/step - loss: 3.9574 - mae: 1.3808 - val_loss: 3.4169 - val_mae: 1.2453

# %% [markdown]
# Evaluate the model

# %%
y_pred = ann.predict(x_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error on Test Set: {mse}")
print(f"R^2 Score on Test Set: {r2}")
# Out:
# 694/694 [==============================] - 1s 1ms/step
# Mean Squared Error on Test Set: 3.60127409328727
# R^2 Score on Test Set: 0.7460958638393045

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Data Records')
plt.ylabel('Precipitation Sum')
plt.title('ANN Regression Model Prediction for Precipitation Sum')
plt.legend()
plt.show()
